# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram

from qiskit_aer import AerSimulator, StatevectorSimulator
import math

# %% [markdown]
# # X-Gate

# %%
psi = [0.5, math.sqrt(3) / 2]
# For execution
simulator = StatevectorSimulator()

qc = QuantumCircuit(1)
qc.initialize(psi, 0)
qc.x(0)

# %%
compiled_circuit = transpile(qc, simulator)
sim_result = simulator.run(compiled_circuit).result()

# %%
plot_histogram(sim_result.get_counts())

# %%
qc.draw('mpl')

# %%
def adjust_weight(state, weights):
    return state[0] * weights[0] + state[1] * weights[1]

# %% [markdown]
# # Hadamard gate

# %%
qc = QuantumCircuit(1)
simulator = StatevectorSimulator()

initial_state = [1, 0]
qc.initialize(initial_state, 0)

qc.h(0)

compiled_circuit = transpile(qc, simulator)
sim_result = simulator.run(compiled_circuit).result()
plot_histogram(sim_result.get_counts())

# %% [markdown]
# ## Reversing hadamard gate

# %%
qc = QuantumCircuit(1)
simulator = StatevectorSimulator()

initial_state = [0, 1]
qc.initialize(initial_state, 0)

qc.h(0)
qc.h(0)

compiled_circuit = transpile(qc, simulator)
sim_result = simulator.run(compiled_circuit).result()
plot_histogram(sim_result.get_counts())

# %% [markdown]
# # Quantum Gambling

# %%
initial_state = [math.sqrt(0.4), math.sqrt(0.6)]

qc = QuantumCircuit(1)
qc.initialize(initial_state, 0)

compiled_circuit = transpile(qc, simulator)
sim_result = simulator.run(compiled_circuit).result()
plot_histogram(sim_result.get_counts())
